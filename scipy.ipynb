# %% [markdown]
# # scipy

# %%
# Numercial arrays.
import numpy as np

# Scientific Computing.
import scipy as sp

# Plotting.
import matplotlib.pyplot as plt

# %% [markdown]
# # Resources
#
# https://docs.scipy.org/doc/scipy/tutorial/index.html

# %% [markdown]
# ## Fit a Line

# %%
# Range of x values.
x = np.linspace(-10.0, 10.0, 21)

# Range of y values.
y = 4.0 * x + 2.0 + np.random.normal(0.0, 3.0, x.shape)

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# %%
# Fit a line.
m, c = np.polyfit(x, y, 1)

# Show.
m, c
# Out:
# (np.float64(4.225059086821392), np.float64(1.9342343608788863))

# %%
# Plot x and y.
plt.plot(x, y, 'o', label='Data')

# Plot the line.
plt.plot(x, m * x + c, label='Fit')

# %%
# Fit a line.
coeffs = np.polyfit(x, y, 1)

# Show.
coeffs
# Out:
# array([4.22505909, 1.93423436])

# %%
# Evaluate the polynomial.
f = np.polyval(coeffs, x)

# Show.
f
# Out:
# array([-40.31635651, -36.09129742, -31.86623833, -27.64117925,
#        -23.41612016, -19.19106107, -14.96600199, -10.7409429 ,
#         -6.51588381,  -2.29082473,   1.93423436,   6.15929345,
#         10.38435253,  14.60941162,  18.83447071,  23.05952979,
#         27.28458888,  31.50964797,  35.73470706,  39.95976614,
#         44.18482523])

# %%
# Show y.
y
# Out:
# array([-41.64572007, -35.00817207, -33.40635468, -29.39533395,
#        -16.56698195, -22.22129774, -16.04562214, -10.03348802,
#         -8.1708317 ,   1.78973479,   2.45677601,   7.40347649,
#         12.63918306,   9.0349259 ,  20.24611522,  20.27656999,
#         25.46185883,  29.66208772,  38.38325875,  37.80982888,
#         47.94890826])

# %% [markdown]
# ## Evaluate
#
# https://en.wikipedia.org/wiki/Coefficient_of_determination

# %%
# Sum of squares of residuals.
ss_res = np.sum((y - f)**2)

# Show.
ss_res
# Out:
# np.float64(165.79730358865595)

# %%
# Mean of y.
y_bar = np.mean(y)

# Show.
y_bar
# Out:
# np.float64(1.9342343608788861)

# %%
# Total sum of squares.
ss_tot = np.sum((y - y_bar)**2)

# Show.
ss_tot
# Out:
# np.float64(13911.163004680295)

# %%
# Ratio.
ss_res / ss_tot
# Out:
# np.float64(0.01191829206033132)

# %%
# R^2 value.
1.0 - (ss_res / ss_tot)
# Out:
# np.float64(0.9880817079396687)

# %% [markdown]
# ## using scipy

# %%
# Use scipy to fit a line.
fit = sp.stats.linregress(x, y)

# Show.
fit
# Out:
# LinregressResult(slope=np.float64(4.22505908682139), intercept=np.float64(1.9342343608788861), rvalue=np.float64(0.994022991655459), pvalue=np.float64(9.62141956362116e-20), stderr=np.float64(0.10645512360460417), intercept_stderr=np.float64(0.6446177853539441))

# %%
# Slope.
fit.slope
# Out:
# np.float64(4.22505908682139)

# %%
# Intercept.
fit.intercept
# Out:
# np.float64(1.9342343608788861)

# %%
# R value.
fit.rvalue
# Out:
# np.float64(0.994022991655459)

# %%
# R2 value.
fit.rvalue**2
# Out:
# np.float64(0.9880817079396688)
